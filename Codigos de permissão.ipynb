# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="testeuser@zeladorx.com.br"
password="TESte2026&"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '92ca37bb8f53bb9a8fbaefad1155c6ab55677c11',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Codigos de permissão disponiveis para uso

# %% [markdown]
# # lista de permissoes de limpeza predial disponiveis

# %%
# os endpointe desse software estao elencados em api/permissions/ListPermissionsLimpezaPredial/
# esses codigos sao uteis para o desnevolvevodor desenvover aplicacoes
response = requests.get("http://127.0.0.1:9000/api/permissions/ListPermissionsLimpezaPredial/", headers=headers)
df = pd.DataFrame(response.json())
display(df)
# Out:
#     id      id_random                                        Permissions
# 0    1   2s4Jp0TQ36Ao     250: Pode criar novas áreas de limpeza predial
# 1    2   Wnp2FouTGhTe          251: Pode editar áreas de limpeza predial
# 2    3   iQZJRE8uOfo4      252: Pode visualizar áreas de limpeza predial
# 3    4   AFKcz6smZblY         253: Pode excluir áreas de limpeza predial
# 4    5   okNpQu4kMWwk    254: Pode desmobilizar áreas de limpeza predial
# 5    6   TbEF7UOU7aOY      255: Pode reabilitar áreas de limpeza predial
# 6    7     TbEF7UOU7a         260: Pode criar novos serviços ao catálogo
# 7    8   vGfGB2OOAbzR              261: Pode editar serviços do catálogo
# 8    9   rbjuUDyNX1W9          262: Pode visualizar serviços do catálogo
# 9   10   4L9plcnOMqxR             263: Pode excluir serviços do catálogo
# 10  11   jlI0PJENlkYs        264: Pode desmobilizar serviços do catálogo
# 11  12   3nnNJf84x1R6          265: Pode reabilitar serviços do catálogo
# ...
