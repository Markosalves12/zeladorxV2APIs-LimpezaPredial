# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="testeuser@zeladorx.com.br"
password="TESte2026&"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '92ca37bb8f53bb9a8fbaefad1155c6ab55677c11',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Configurações dos usuário

# %%
# retorna o estsado atual de configuracao de todos os usuarios que é permitido visualizar
# vem de api/gerentes/ListGerenteLimpezaPredial/
# codigo de permissão necessário --> 410: Pode editar o recebimento de notificações gerais
# essa perissao caracteriza a visualizacao na api, no apçlicativo o usuario so tem acesso a sua propria configuracao
response = requests.get("http://127.0.0.1:9000/api/settings/ListSettingServicosGerenteLimpezaPredial/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
# Out:
#    id     id_random  Gerente  NotificationsServicosAtrasados  \
# 0   1  VGmPYy0gKTu9        6                           False
#
#    NotificationsServicosProximos  NotificationsServicosEmAndamento  \
# 0                          False                             False
#
#    NotificationsServicosCancelados  NotificationsServicosAgendados  \
# 0                            False                           False
#
#    NotificationReportProductivity  NotificationReportServicosAtrasados  \
# 0                           False                                False
#
#    NotificationReportServicosProximos  NotificationReportServicosEmAndamento  \
# 0                               False                                  False
#
#    NotificationReportServicosCancelados
# 0                                 False

# %% [markdown]
# # configurações do usuario por usuario

# %%
# recebe o id_random da configuracao como parametro de url
# retorna a configuracao de um usuario especifico, sendo identificado pelo id_random
# codigo de permissão necessário --> 410: Pode editar o recebimento de notificações gerais
response = requests.get("http://127.0.0.1:9000/api/settings/SettingServicosGerenteLimpezaPredialDetail/VGmPYy0gKTu9/", headers=headers)
response.json()
# Out:
# {'id': 1,
#  'id_random': 'VGmPYy0gKTu9',
#  'Gerente': 6,
#  'NotificationsServicosAtrasados': False,
#  'NotificationsServicosProximos': False,
#  'NotificationsServicosEmAndamento': False,
#  'NotificationsServicosCancelados': False,
#  'NotificationsServicosAgendados': False,
#  'NotificationReportProductivity': False,
#  'NotificationReportServicosAtrasados': False,
#  'NotificationReportServicosProximos': False,
#  'NotificationReportServicosEmAndamento': False,
#  'NotificationReportServicosCancelados': False}

# %% [markdown]
# # atualizar configurações por usuários

# %%
body = {
    'Gerente': 6, # vem de api/gerentes/ListGerenteLimpezaPredial/
    'NotificationsServicosAtrasados': "true",
    'NotificationsServicosProximos': "true",
    'NotificationsServicosEmAndamento': "",
    'NotificationsServicosCancelados': "true",
    'NotificationsServicosAgendados': "",
    'NotificationReportProductivity': "true",
    'NotificationReportServicosAtrasados': "",
    'NotificationReportServicosProximos': "true",
    'NotificationReportServicosEmAndamento': "",
    'NotificationReportServicosCancelados': "true",
}

# %%
# atualiza o cinjunto de permissoe s de um usuario
# codigo de permissão necessário --> 410: Pode editar o recebimento de notificações gerais
response = requests.put("http://127.0.0.1:9000/api/settings/SettingServicosGerenteLimpezaPredialUpdate/VGmPYy0gKTu9/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': 'SettingServicosGerenteLimpezaPredial atualizado com sucesso.',
#  'data': {'id': 1,
#   'id_random': 'VGmPYy0gKTu9',
#   'Gerente': 6,
#   'NotificationsServicosAtrasados': True,
#   'NotificationsServicosProximos': True,
#   'NotificationsServicosEmAndamento': None,
#   'NotificationsServicosCancelados': True,
#   'NotificationsServicosAgendados': None,
#   'NotificationReportProductivity': True,
#   'NotificationReportServicosAtrasados': None,
#   'NotificationReportServicosProximos': True,
#   'NotificationReportServicosEmAndamento': None,
#   'NotificationReportServicosCancelados': True}}
